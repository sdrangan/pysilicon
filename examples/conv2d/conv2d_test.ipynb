# %%
from conv2d_demo import Conv2DTest

# %%
ct = Conv2DTest()
ct.gen_vitis_code()
# Out:
# [WindowsPath('C:/Users/sdran/Documents/repos/pysilicon/examples/conv2d/include/conv2_d_error.h'),
#  WindowsPath('C:/Users/sdran/Documents/repos/pysilicon/examples/conv2d/include/conv2_d_cmd.h'),
#  WindowsPath('C:/Users/sdran/Documents/repos/pysilicon/examples/conv2d/include/conv2_d_resp.h'),
#  WindowsPath('C:/Users/sdran/Documents/repos/pysilicon/examples/conv2d/include/uint8_array_utils.h'),
#  WindowsPath('C:/Users/sdran/Documents/repos/pysilicon/examples/conv2d/include/int8_array_utils.h')]

# %%
# Test integer conv2d
import numpy as np
from scipy.signal import convolve2d

image = np.random.randint(0, 256, size=(16, 16), dtype=np.uint32)
kernel = np.random.randint(-128, 128, size=(3, 3), dtype=np.int32)


out = convolve2d(image, kernel,
                mode="same", boundary="fill", fillvalue=0
            )

# %%
print(out.shape)
print(out.dtype)
# Out:
# (16, 16)
# int64
